# %%
from ExtractBootlegFeatures1 import *
import fitz

# %%
'''
# 将PDF转化为图片
pdfPath pdf文件的路径
imgPath 图像要保存的文件夹
zoom_x x方向的缩放系数
zoom_y y方向的缩放系数
rotation_angle 旋转角度
'''
def pdf_image(pdfPath,imgPath,zoom_x,zoom_y,rotation_angle):
    # 打开PDF文件
    pdf = fitz.open(pdfPath)
    # 逐页读取PDF
    for pg in range(0, pdf.pageCount):
        page = pdf[pg]
        # 设置缩放和旋转系数
        trans = fitz.Matrix(zoom_x, zoom_y).prerotate(rotation_angle)
        pm = page.get_pixmap(matrix=trans, alpha=False)
        # 开始写图像
        pm.save(imgPath+str(pg)+".png")
    pdf.close()

# %%
pdfdir = "MSMD_pdf"
outbasedir = "MSMD_png"
for root,dirs,files in os.walk(pdfdir):
    for file in files:
        os.makedirs(os.path.join(outbasedir,os.path.splitext(file)[0]))

# %%
pdfpath = "MSMD_pdf/AdamA__giselle__giselle_ly.pdf"
outpath = "./"
pdf_image(pdfpath,outpath,4.28,4.28,0)

# %%
for root,dirs,files in os.walk("MSMD_pdf"):
    for file in files:
        pdfpath = os.path.join(root,file)
        imgpath = os.path.join("MSMD_png",os.path.splitext(file)[0])+'/'
        pdf_image(pdfpath,imgpath,4.28,4.28,0)

# %%
for root,dirs,files in os.walk("MSMD_png"):
    for file in files:
        im = Image.open(os.path.join(root,file))
        print(im.size)
# Out:
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# (2548, 3604)
# ...

# %%
for i in range(2):
    im = Image.open(str(i)+".png")
    print(im.size)
# Out:
# (2548, 3604)
# (2548, 3604)

# %%
def processImageDir(dirin,outfile = "outfile.txt"):
    files = os.listdir(dirin)
    bscore_total = np.zeros((62,1))
    outdir = "MSMD_pkl"
    for i in range(len(files)):
        impath = os.path.join(dirin,str(i)+".png")
        bscore_page = processImageFile(impath,outfile)
        if len(bscore_page.shape)==2:
            bscore_total = np.concatenate((bscore_total,bscore_page),axis = 1)
    outfile = os.path.join(outdir,os.path.split(dirin)[-1]+".pkl")
    with open(outfile,"wb")as f:
        pickle.dump(bscore_total,f)
    print(bscore_total.shape)

# %%
dirs = os.listdir("MSMD_png")
for i in range(284,len(dirs)):
    processImageDir(os.path.join("MSMD_png",dir))

# %%
dirs[284]
# Out:
# 'HanonCL__virtuoso-pianist-pt1__hanon-book_ly'
